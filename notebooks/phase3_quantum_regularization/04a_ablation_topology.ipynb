# %% [markdown]
# # **SPECTRA-CQ: Optimized HQAE Entanglement Topology Ablation**
#
# This notebook executes the first half of the optimized HQAE ablation study.
#
# To mathematically prove whether quantum entanglement provides an advantage in mapping structural degradation, we **lock the circuit depth at 3 layers** and test three distinct quantum topologies:
#
# 1. **None (The Control):** Zero entanglement. Qubits operate independently.
# 2. **Basic (The Baseline):** Localized ring entanglement. Qubits only interact with their immediate neighbors.
# 3. **Strong (The Optimization):** All-to-all entanglement with generalized 3D Euler rotations.
#
# **Crash Recovery Protocol:** Each topology is executed in an isolated cell. Logs and model weights are streamed directly to Google Drive. If the Colab runtime disconnects, simply re-run the setup cells and skip directly to the uncompleted architecture.

# %%
from google.colab import drive
import os

# Mount Data Drive
drive.mount('/content/drive')

# Clone Github Repository
# Used a PAT here because the GitHub repo was private during our runs
# Scrubbed the actual token before downloading/documenting for security
GITHUB_TOKEN = "PAT"
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/yeshapan/SPECTRA-CQ.git"

# !git clone {REPO_URL}
# %cd SPECTRA-CQ
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# Cloning into 'SPECTRA-CQ'...
# remote: Enumerating objects: 260, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 260 (delta 72), reused 162 (delta 48), pack-reused 73 (from 1)
# Receiving objects: 100% (260/260), 33.36 MiB | 25.13 MiB/s, done.
# Resolving deltas: 100% (82/82), done.
# /content/SPECTRA-CQ
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.11.0+cpu)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.26.0+cpu)
# Collecting pennylane>=0.37.0 (from -r requirements.txt (line 6))
#   Downloading pennylane-0.45.0-py3-none-any.whl.metadata (10 kB)
# Collecting qiskit<2.0.0,>=1.1.0 (from -r requirements.txt (line 7))
#   Downloading qiskit-1.4.6-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Collecting qiskit-machine-learning<0.9.0,>=0.8.0 (from -r requirements.txt (line 8))
#   Downloading qiskit_machine_learning-0.8.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (2.2.2)
# Requirement already satisfied: PyWavelets>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (1.9.0)
# Requirement already satisfied: h5py>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (3.16.0)
# Collecting scipy<1.15.0,>=1.10.0 (from -r requirements.txt (line 15))
#   Downloading scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (3.10.0)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (0.13.2)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (4.67.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.15.0->-r requirements.txt (line 3)) (11.3.0)
# Collecting rustworkx>=0.14.0 (from pennylane>=0.37.0->-r requirements.txt (line 6))
#   Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from pennylane>=0.37.0->-r requirements.txt (line 6)) (1.8.0)
# Collecting appdirs (from pennylane>=0.37.0->-r requirements.txt (line 6))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.4 (from pennylane>=0.37.0->-r requirements.txt (line 6))
#   Downloading autoray-0.8.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from pennylane>=0.37.0->-r requirements.txt (line 6)) (6.2.6)
# Collecting pennylane-lightning>=0.45 (from pennylane>=0.37.0->-r requirements.txt (line 6))
#   Downloading pennylane_lightning-0.45.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pennylane>=0.37.0->-r requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.12/dist-packages (from pennylane>=0.37.0->-r requirements.txt (line 6)) (0.13.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pennylane>=0.37.0->-r requirements.txt (line 6)) (26.2)
# Collecting diastatic-malt (from pennylane>=0.37.0->-r requirements.txt (line 6))
#   Downloading diastatic_malt-2.15.3-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: gast in /usr/local/lib/python3.12/dist-packages (from pennylane>=0.37.0->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit<2.0.0,>=1.1.0->-r requirements.txt (line 7)) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit<2.0.0,>=1.1.0->-r requirements.txt (line 7)) (2.9.0.post0)
# Collecting stevedore>=3.0.0 (from qiskit<2.0.0,>=1.1.0->-r requirements.txt (line 7))
#   Downloading stevedore-5.8.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting symengine<0.14,>=0.11 (from qiskit<2.0.0,>=1.1.0->-r requirements.txt (line 7))
#   Downloading symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 12)) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (3.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 21)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 21)) (3.6.0)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.45->pennylane>=0.37.0->-r requirements.txt (line 6))
#   Downloading scipy_openblas32-0.3.33.112.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit<2.0.0,>=1.1.0->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane>=0.37.0->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane>=0.37.0->-r requirements.txt (line 6)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane>=0.37.0->-r requirements.txt (line 6)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane>=0.37.0->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane>=0.37.0->-r requirements.txt (line 6)) (2026.5.20)
# Downloading pennylane-0.45.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 84.2 MB/s eta 0:00:00
# Downloading autoray-0.8.4-py3-none-any.whl (937 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.5/937.5 kB 41.0 MB/s eta 0:00:00
# Downloading qiskit-1.4.6-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 69.7 MB/s eta 0:00:00
# Downloading qiskit_machine_learning-0.8.4-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 16.8 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 14.7 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.45.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (25.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 51.1 MB/s eta 0:00:00
# Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 58.3 MB/s eta 0:00:00
# Downloading stevedore-5.8.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.3 MB/s eta 0:00:00
# Downloading symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 18.0 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.3-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 kB 12.0 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.33.112.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 98.2 MB/s eta 0:00:00
# Installing collected packages: appdirs, symengine, stevedore, scipy-openblas32, scipy, rustworkx, diastatic-malt, autoray, qiskit, qiskit-machine-learning, pennylane-lightning, pennylane
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
# Successfully installed appdirs-1.4.4 autoray-0.8.4 diastatic-malt-2.15.3 pennylane-0.45.0 pennylane-lightning-0.45.0 qiskit-1.4.6 qiskit-machine-learning-0.8.4 rustworkx-0.18.0 scipy-1.14.1 scipy-openblas32-0.3.33.112.0 stevedore-5.8.0 symengine-0.13.0

# %%
# Hardware Verification
import torch

if torch.cuda.is_available():
    print(f"Hardware Accelerator Confirmed: {torch.cuda.get_device_name(0)}")
    print(f"CUDA Version: {torch.version.cuda}")
else:
    print("FATAL WARNING: GPU not detected. The training protocol will take exponentially longer on a CPU.")
    print("Please navigate to Runtime > Change runtime type > T4 GPU.")
# Out:
# Hardware Accelerator Confirmed: Tesla T4
# CUDA Version: 12.8

# %%
# I/O Optimization
# Copy the zip from Drive to local NVMe first
# !cp /content/drive/MyDrive/spectra-cq-data/spectra_matrices_PE11.zip /content/

# Extract directly into the base directory
# !unzip -q /content/spectra_matrices_PE11.zip -d /content/local_spectra_data/
print("Data extraction complete")

# Clean up the local zip file
# !rm /content/spectra_matrices_PE11.zip

# Create persistent log directory on Drive for Ablation 4a
# !mkdir -p /content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/phase4a

print("Log directory for phase-3 ablation-4a created in Drive")
# Out:
# Data extraction complete
# Log directory for phase 4a created in Drive

# %% [markdown]
# ### **Experiment 1: Zero Entanglement (`none`)**
# This execution strips out all `CNOT` gates $\rightarrow$ effectively reduces the VQC to a series of independent rotations.
#
# In Leg-1, this model exhibited extreme "instantiation roulette" due to unconstrained classical-quantum gradient explosions.
#
# If our Leg-2 gradient clipping mitigation is successful, this topology should now converge smoothly across all 3 seeds without wild MSE fluctuations.

# %%
# Execute the pipeline and pipe the terminal output to both the screen and a persistent log file
# !python scripts/run_experiment.py --config configs/ablation_hqae_none_d3.yaml 2>&1 | tee /content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/none_d3.log
# Out:
# 2026-06-23 09:54:28,608 - INFO - Compute device allocated: cuda
# 2026-06-23 09:54:28,608 - INFO - Starting Protocol Run | Seed: 42
# 2026-06-23 09:54:28,611 - INFO - System locked to deterministic seed: 42
# 2026-06-23 09:54:28,900 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 09:54:34,144 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 09:55:36,843 - INFO - Epoch 1/15 | Train MSE: 0.040704 | Val MSE: 0.032223 | LR: 1.00e-03
# 2026-06-23 09:55:36,865 - INFO - New optimal weights saved. Validation Loss: 0.032223
# 2026-06-23 09:56:31,905 - INFO - Epoch 2/15 | Train MSE: 0.031999 | Val MSE: 0.032076 | LR: 1.00e-03
# 2026-06-23 09:56:31,918 - INFO - New optimal weights saved. Validation Loss: 0.032076
# 2026-06-23 09:57:24,981 - INFO - Epoch 3/15 | Train MSE: 0.031905 | Val MSE: 0.032012 | LR: 1.00e-03
# 2026-06-23 09:57:24,993 - INFO - New optimal weights saved. Validation Loss: 0.032012
# 2026-06-23 09:58:16,545 - INFO - Epoch 4/15 | Train MSE: 0.023937 | Val MSE: 0.014676 | LR: 1.00e-03
# 2026-06-23 09:58:16,556 - INFO - New optimal weights saved. Validation Loss: 0.014676
# 2026-06-23 09:59:09,512 - INFO - Epoch 5/15 | Train MSE: 0.013536 | Val MSE: 0.012183 | LR: 1.00e-03
# 2026-06-23 09:59:09,546 - INFO - New optimal weights saved. Validation Loss: 0.012183
# 2026-06-23 10:00:01,801 - INFO - Epoch 6/15 | Train MSE: 0.010240 | Val MSE: 0.009368 | LR: 1.00e-03
# 2026-06-23 10:00:01,816 - INFO - New optimal weights saved. Validation Loss: 0.009368
# 2026-06-23 10:00:54,356 - INFO - Epoch 7/15 | Train MSE: 0.009522 | Val MSE: 0.009225 | LR: 1.00e-03
# 2026-06-23 10:00:54,369 - INFO - New optimal weights saved. Validation Loss: 0.009225
# 2026-06-23 10:01:47,345 - INFO - Epoch 8/15 | Train MSE: 0.009332 | Val MSE: 0.009087 | LR: 1.00e-03
# 2026-06-23 10:01:47,364 - INFO - New optimal weights saved. Validation Loss: 0.009087
# 2026-06-23 10:02:38,521 - INFO - Epoch 9/15 | Train MSE: 0.009223 | Val MSE: 0.008965 | LR: 1.00e-03
# 2026-06-23 10:02:38,535 - INFO - New optimal weights saved. Validation Loss: 0.008965
# 2026-06-23 10:03:31,225 - INFO - Epoch 10/15 | Train MSE: 0.009157 | Val MSE: 0.008913 | LR: 1.00e-03
# 2026-06-23 10:03:31,239 - INFO - New optimal weights saved. Validation Loss: 0.008913
# 2026-06-23 10:04:22,689 - INFO - Epoch 11/15 | Train MSE: 0.009108 | Val MSE: 0.008880 | LR: 1.00e-03
# 2026-06-23 10:04:22,701 - INFO - New optimal weights saved. Validation Loss: 0.008880
# 2026-06-23 10:05:14,565 - INFO - Epoch 12/15 | Train MSE: 0.009044 | Val MSE: 0.008879 | LR: 1.00e-03
# 2026-06-23 10:05:14,577 - INFO - New optimal weights saved. Validation Loss: 0.008879
# 2026-06-23 10:06:07,580 - INFO - Epoch 13/15 | Train MSE: 0.009033 | Val MSE: 0.009058 | LR: 1.00e-03
# 2026-06-23 10:06:59,330 - INFO - Epoch 14/15 | Train MSE: 0.008997 | Val MSE: 0.008766 | LR: 1.00e-03
# 2026-06-23 10:06:59,342 - INFO - New optimal weights saved. Validation Loss: 0.008766
# 2026-06-23 10:07:56,652 - INFO - Epoch 15/15 | Train MSE: 0.008979 | Val MSE: 0.008750 | LR: 1.00e-03
# 2026-06-23 10:07:56,665 - INFO - New optimal weights saved. Validation Loss: 0.008750
# 2026-06-23 10:07:56,665 - INFO - Starting Protocol Run | Seed: 100
# 2026-06-23 10:07:56,667 - INFO - System locked to deterministic seed: 100
# 2026-06-23 10:07:56,707 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 10:07:56,714 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 10:08:52,197 - INFO - Epoch 1/15 | Train MSE: 0.052723 | Val MSE: 0.032518 | LR: 1.00e-03
# 2026-06-23 10:08:52,214 - INFO - New optimal weights saved. Validation Loss: 0.032518
# 2026-06-23 10:09:45,685 - INFO - Epoch 2/15 | Train MSE: 0.032205 | Val MSE: 0.032158 | LR: 1.00e-03
# 2026-06-23 10:09:45,699 - INFO - New optimal weights saved. Validation Loss: 0.032158
# 2026-06-23 10:10:38,707 - INFO - Epoch 3/15 | Train MSE: 0.032014 | Val MSE: 0.032064 | LR: 1.00e-03
# 2026-06-23 10:10:38,719 - INFO - New optimal weights saved. Validation Loss: 0.032064
# 2026-06-23 10:11:32,649 - INFO - Epoch 4/15 | Train MSE: 0.031960 | Val MSE: 0.032038 | LR: 1.00e-03
# 2026-06-23 10:11:32,662 - INFO - New optimal weights saved. Validation Loss: 0.032038
# 2026-06-23 10:12:25,785 - INFO - Epoch 5/15 | Train MSE: 0.031887 | Val MSE: 0.031980 | LR: 1.00e-03
# 2026-06-23 10:12:25,799 - INFO - New optimal weights saved. Validation Loss: 0.031980
# 2026-06-23 10:13:18,339 - INFO - Epoch 6/15 | Train MSE: 0.024013 | Val MSE: 0.013778 | LR: 1.00e-03
# 2026-06-23 10:13:18,351 - INFO - New optimal weights saved. Validation Loss: 0.013778
# 2026-06-23 10:14:13,298 - INFO - Epoch 7/15 | Train MSE: 0.011813 | Val MSE: 0.010577 | LR: 1.00e-03
# 2026-06-23 10:14:13,311 - INFO - New optimal weights saved. Validation Loss: 0.010577
# 2026-06-23 10:15:05,907 - INFO - Epoch 8/15 | Train MSE: 0.010362 | Val MSE: 0.009777 | LR: 1.00e-03
# 2026-06-23 10:15:05,921 - INFO - New optimal weights saved. Validation Loss: 0.009777
# 2026-06-23 10:15:59,706 - INFO - Epoch 9/15 | Train MSE: 0.009948 | Val MSE: 0.009630 | LR: 1.00e-03
# 2026-06-23 10:15:59,719 - INFO - New optimal weights saved. Validation Loss: 0.009630
# 2026-06-23 10:16:53,519 - INFO - Epoch 10/15 | Train MSE: 0.009710 | Val MSE: 0.009404 | LR: 1.00e-03
# 2026-06-23 10:16:53,539 - INFO - New optimal weights saved. Validation Loss: 0.009404
# 2026-06-23 10:17:45,620 - INFO - Epoch 11/15 | Train MSE: 0.009308 | Val MSE: 0.008919 | LR: 1.00e-03
# 2026-06-23 10:17:45,632 - INFO - New optimal weights saved. Validation Loss: 0.008919
# 2026-06-23 10:18:40,155 - INFO - Epoch 12/15 | Train MSE: 0.009154 | Val MSE: 0.008855 | LR: 1.00e-03
# 2026-06-23 10:18:40,167 - INFO - New optimal weights saved. Validation Loss: 0.008855
# 2026-06-23 10:19:34,801 - INFO - Epoch 13/15 | Train MSE: 0.009084 | Val MSE: 0.008973 | LR: 1.00e-03
# 2026-06-23 10:20:27,211 - INFO - Epoch 14/15 | Train MSE: 0.009054 | Val MSE: 0.008836 | LR: 1.00e-03
# 2026-06-23 10:20:27,224 - INFO - New optimal weights saved. Validation Loss: 0.008836
# 2026-06-23 10:21:20,489 - INFO - Epoch 15/15 | Train MSE: 0.009019 | Val MSE: 0.008756 | LR: 1.00e-03
# 2026-06-23 10:21:20,502 - INFO - New optimal weights saved. Validation Loss: 0.008756
# 2026-06-23 10:21:20,502 - INFO - Starting Protocol Run | Seed: 2026
# 2026-06-23 10:21:20,503 - INFO - System locked to deterministic seed: 2026
# 2026-06-23 10:21:20,542 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 10:21:20,547 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 10:22:13,730 - INFO - Epoch 1/15 | Train MSE: 0.039779 | Val MSE: 0.032225 | LR: 1.00e-03
# 2026-06-23 10:22:13,751 - INFO - New optimal weights saved. Validation Loss: 0.032225
# 2026-06-23 10:23:06,426 - INFO - Epoch 2/15 | Train MSE: 0.032055 | Val MSE: 0.032145 | LR: 1.00e-03
# 2026-06-23 10:23:06,455 - INFO - New optimal weights saved. Validation Loss: 0.032145
# 2026-06-23 10:24:05,360 - INFO - Epoch 3/15 | Train MSE: 0.031914 | Val MSE: 0.031914 | LR: 1.00e-03
# 2026-06-23 10:24:05,374 - INFO - New optimal weights saved. Validation Loss: 0.031914
# 2026-06-23 10:25:03,575 - INFO - Epoch 4/15 | Train MSE: 0.028904 | Val MSE: 0.017164 | LR: 1.00e-03
# 2026-06-23 10:25:03,589 - INFO - New optimal weights saved. Validation Loss: 0.017164
# 2026-06-23 10:26:02,676 - INFO - Epoch 5/15 | Train MSE: 0.013963 | Val MSE: 0.010558 | LR: 1.00e-03
# 2026-06-23 10:26:02,690 - INFO - New optimal weights saved. Validation Loss: 0.010558
# 2026-06-23 10:27:00,712 - INFO - Epoch 6/15 | Train MSE: 0.010148 | Val MSE: 0.009395 | LR: 1.00e-03
# 2026-06-23 10:27:00,724 - INFO - New optimal weights saved. Validation Loss: 0.009395
# 2026-06-23 10:27:57,845 - INFO - Epoch 7/15 | Train MSE: 0.009680 | Val MSE: 0.009240 | LR: 1.00e-03
# 2026-06-23 10:27:57,858 - INFO - New optimal weights saved. Validation Loss: 0.009240
# 2026-06-23 10:28:54,731 - INFO - Epoch 8/15 | Train MSE: 0.009480 | Val MSE: 0.009101 | LR: 1.00e-03
# 2026-06-23 10:28:54,748 - INFO - New optimal weights saved. Validation Loss: 0.009101
# 2026-06-23 10:29:49,269 - INFO - Epoch 9/15 | Train MSE: 0.009360 | Val MSE: 0.009007 | LR: 1.00e-03
# 2026-06-23 10:29:49,282 - INFO - New optimal weights saved. Validation Loss: 0.009007
# 2026-06-23 10:30:44,786 - INFO - Epoch 10/15 | Train MSE: 0.009292 | Val MSE: 0.008970 | LR: 1.00e-03
# 2026-06-23 10:30:44,798 - INFO - New optimal weights saved. Validation Loss: 0.008970
# 2026-06-23 10:31:40,754 - INFO - Epoch 11/15 | Train MSE: 0.009244 | Val MSE: 0.008976 | LR: 1.00e-03
# 2026-06-23 10:32:35,437 - INFO - Epoch 12/15 | Train MSE: 0.009171 | Val MSE: 0.008863 | LR: 1.00e-03
# 2026-06-23 10:32:35,455 - INFO - New optimal weights saved. Validation Loss: 0.008863
# 2026-06-23 10:33:30,522 - INFO - Epoch 13/15 | Train MSE: 0.009119 | Val MSE: 0.008912 | LR: 1.00e-03
# 2026-06-23 10:34:25,522 - INFO - Epoch 14/15 | Train MSE: 0.009084 | Val MSE: 0.008810 | LR: 1.00e-03
# 2026-06-23 10:34:25,535 - INFO - New optimal weights saved. Validation Loss: 0.008810
# 2026-06-23 10:35:21,466 - INFO - Epoch 15/15 | Train MSE: 0.009060 | Val MSE: 0.009041 | LR: 1.00e-03
# 2026-06-23 10:35:21,466 - INFO - All seed protocols completed successfully.

# %% [markdown]
# ### **Experiment 2: Localized Ring Entanglement (`basic`)**
# Qubits only entangle with their immediate neighbors, simulating localized frequency coupling.
#
# Observe how the intermediate entanglement complexity reacts to the new Identity Block initialization.

# %%
# !python scripts/run_experiment.py --config configs/ablation_hqae_basic_d3.yaml 2>&1 | tee /content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/basic_d3.log
# Out:
# 2026-06-23 10:35:39,004 - INFO - Compute device allocated: cuda
# 2026-06-23 10:35:39,005 - INFO - Starting Protocol Run | Seed: 42
# 2026-06-23 10:35:39,008 - INFO - System locked to deterministic seed: 42
# 2026-06-23 10:35:39,064 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 10:35:40,612 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 10:36:47,864 - INFO - Epoch 1/15 | Train MSE: 0.040871 | Val MSE: 0.032252 | LR: 1.00e-03
# 2026-06-23 10:36:47,887 - INFO - New optimal weights saved. Validation Loss: 0.032252
# 2026-06-23 10:37:53,289 - INFO - Epoch 2/15 | Train MSE: 0.032004 | Val MSE: 0.032006 | LR: 1.00e-03
# 2026-06-23 10:37:53,304 - INFO - New optimal weights saved. Validation Loss: 0.032006
# 2026-06-23 10:39:00,556 - INFO - Epoch 3/15 | Train MSE: 0.031883 | Val MSE: 0.032061 | LR: 1.00e-03
# 2026-06-23 10:40:09,107 - INFO - Epoch 4/15 | Train MSE: 0.031875 | Val MSE: 0.032075 | LR: 1.00e-03
# 2026-06-23 10:41:18,937 - INFO - Epoch 5/15 | Train MSE: 0.031715 | Val MSE: 0.031601 | LR: 1.00e-03
# 2026-06-23 10:41:18,950 - INFO - New optimal weights saved. Validation Loss: 0.031601
# 2026-06-23 10:42:26,426 - INFO - Epoch 6/15 | Train MSE: 0.030985 | Val MSE: 0.030418 | LR: 1.00e-03
# 2026-06-23 10:42:26,446 - INFO - New optimal weights saved. Validation Loss: 0.030418
# 2026-06-23 10:43:33,532 - INFO - Epoch 7/15 | Train MSE: 0.026278 | Val MSE: 0.021882 | LR: 1.00e-03
# 2026-06-23 10:43:33,545 - INFO - New optimal weights saved. Validation Loss: 0.021882
# 2026-06-23 10:44:40,844 - INFO - Epoch 8/15 | Train MSE: 0.019581 | Val MSE: 0.017610 | LR: 1.00e-03
# 2026-06-23 10:44:40,857 - INFO - New optimal weights saved. Validation Loss: 0.017610
# 2026-06-23 10:45:47,169 - INFO - Epoch 9/15 | Train MSE: 0.016038 | Val MSE: 0.014569 | LR: 1.00e-03
# 2026-06-23 10:45:47,182 - INFO - New optimal weights saved. Validation Loss: 0.014569
# 2026-06-23 10:46:57,601 - INFO - Epoch 10/15 | Train MSE: 0.014434 | Val MSE: 0.013756 | LR: 1.00e-03
# 2026-06-23 10:46:57,614 - INFO - New optimal weights saved. Validation Loss: 0.013756
# 2026-06-23 10:48:06,425 - INFO - Epoch 11/15 | Train MSE: 0.013706 | Val MSE: 0.013162 | LR: 1.00e-03
# 2026-06-23 10:48:06,440 - INFO - New optimal weights saved. Validation Loss: 0.013162
# 2026-06-23 10:49:14,844 - INFO - Epoch 12/15 | Train MSE: 0.013184 | Val MSE: 0.013122 | LR: 1.00e-03
# 2026-06-23 10:49:14,864 - INFO - New optimal weights saved. Validation Loss: 0.013122
# 2026-06-23 10:50:23,336 - INFO - Epoch 13/15 | Train MSE: 0.012925 | Val MSE: 0.012542 | LR: 1.00e-03
# 2026-06-23 10:50:23,350 - INFO - New optimal weights saved. Validation Loss: 0.012542
# 2026-06-23 10:51:32,286 - INFO - Epoch 14/15 | Train MSE: 0.012743 | Val MSE: 0.013835 | LR: 1.00e-03
# 2026-06-23 10:52:39,807 - INFO - Epoch 15/15 | Train MSE: 0.012636 | Val MSE: 0.012512 | LR: 1.00e-03
# 2026-06-23 10:52:39,820 - INFO - New optimal weights saved. Validation Loss: 0.012512
# 2026-06-23 10:52:39,820 - INFO - Starting Protocol Run | Seed: 100
# 2026-06-23 10:52:39,823 - INFO - System locked to deterministic seed: 100
# 2026-06-23 10:52:39,864 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 10:52:39,871 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 10:53:46,361 - INFO - Epoch 1/15 | Train MSE: 0.053066 | Val MSE: 0.032598 | LR: 1.00e-03
# 2026-06-23 10:53:46,379 - INFO - New optimal weights saved. Validation Loss: 0.032598
# 2026-06-23 10:54:54,192 - INFO - Epoch 2/15 | Train MSE: 0.032188 | Val MSE: 0.032168 | LR: 1.00e-03
# 2026-06-23 10:54:54,206 - INFO - New optimal weights saved. Validation Loss: 0.032168
# 2026-06-23 10:56:02,898 - INFO - Epoch 3/15 | Train MSE: 0.031644 | Val MSE: 0.024309 | LR: 1.00e-03
# 2026-06-23 10:56:02,911 - INFO - New optimal weights saved. Validation Loss: 0.024309
# 2026-06-23 10:57:10,083 - INFO - Epoch 4/15 | Train MSE: 0.017028 | Val MSE: 0.013743 | LR: 1.00e-03
# 2026-06-23 10:57:10,098 - INFO - New optimal weights saved. Validation Loss: 0.013743
# 2026-06-23 10:58:18,752 - INFO - Epoch 5/15 | Train MSE: 0.013028 | Val MSE: 0.012352 | LR: 1.00e-03
# 2026-06-23 10:58:18,764 - INFO - New optimal weights saved. Validation Loss: 0.012352
# 2026-06-23 10:59:25,167 - INFO - Epoch 6/15 | Train MSE: 0.012113 | Val MSE: 0.011641 | LR: 1.00e-03
# 2026-06-23 10:59:25,182 - INFO - New optimal weights saved. Validation Loss: 0.011641
# 2026-06-23 11:00:31,635 - INFO - Epoch 7/15 | Train MSE: 0.011777 | Val MSE: 0.011652 | LR: 1.00e-03
# 2026-06-23 11:01:38,445 - INFO - Epoch 8/15 | Train MSE: 0.011543 | Val MSE: 0.012636 | LR: 1.00e-03
# 2026-06-23 11:02:44,525 - INFO - Epoch 9/15 | Train MSE: 0.011395 | Val MSE: 0.011226 | LR: 1.00e-03
# 2026-06-23 11:02:44,538 - INFO - New optimal weights saved. Validation Loss: 0.011226
# 2026-06-23 11:03:49,587 - INFO - Epoch 10/15 | Train MSE: 0.011191 | Val MSE: 0.011127 | LR: 1.00e-03
# 2026-06-23 11:03:49,604 - INFO - New optimal weights saved. Validation Loss: 0.011127
# 2026-06-23 11:04:56,541 - INFO - Epoch 11/15 | Train MSE: 0.011041 | Val MSE: 0.010815 | LR: 1.00e-03
# 2026-06-23 11:04:56,554 - INFO - New optimal weights saved. Validation Loss: 0.010815
# 2026-06-23 11:06:01,766 - INFO - Epoch 12/15 | Train MSE: 0.010890 | Val MSE: 0.010689 | LR: 1.00e-03
# 2026-06-23 11:06:01,781 - INFO - New optimal weights saved. Validation Loss: 0.010689
# 2026-06-23 11:07:05,954 - INFO - Epoch 13/15 | Train MSE: 0.010738 | Val MSE: 0.010858 | LR: 1.00e-03
# 2026-06-23 11:08:11,005 - INFO - Epoch 14/15 | Train MSE: 0.010608 | Val MSE: 0.010761 | LR: 1.00e-03
# 2026-06-23 11:09:18,585 - INFO - Epoch 15/15 | Train MSE: 0.010514 | Val MSE: 0.010206 | LR: 1.00e-03
# 2026-06-23 11:09:18,598 - INFO - New optimal weights saved. Validation Loss: 0.010206
# 2026-06-23 11:09:18,598 - INFO - Starting Protocol Run | Seed: 2026
# 2026-06-23 11:09:18,599 - INFO - System locked to deterministic seed: 2026
# 2026-06-23 11:09:18,647 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 11:09:18,653 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 11:10:24,338 - INFO - Epoch 1/15 | Train MSE: 0.039901 | Val MSE: 0.032237 | LR: 1.00e-03
# 2026-06-23 11:10:24,356 - INFO - New optimal weights saved. Validation Loss: 0.032237
# 2026-06-23 11:11:29,843 - INFO - Epoch 2/15 | Train MSE: 0.032045 | Val MSE: 0.032124 | LR: 1.00e-03
# 2026-06-23 11:11:29,856 - INFO - New optimal weights saved. Validation Loss: 0.032124
# 2026-06-23 11:12:33,309 - INFO - Epoch 3/15 | Train MSE: 0.031916 | Val MSE: 0.031923 | LR: 1.00e-03
# 2026-06-23 11:12:33,321 - INFO - New optimal weights saved. Validation Loss: 0.031923
# 2026-06-23 11:13:37,715 - INFO - Epoch 4/15 | Train MSE: 0.021461 | Val MSE: 0.016426 | LR: 1.00e-03
# 2026-06-23 11:13:37,727 - INFO - New optimal weights saved. Validation Loss: 0.016426
# 2026-06-23 11:14:41,228 - INFO - Epoch 5/15 | Train MSE: 0.015706 | Val MSE: 0.014716 | LR: 1.00e-03
# 2026-06-23 11:14:41,240 - INFO - New optimal weights saved. Validation Loss: 0.014716
# 2026-06-23 11:15:43,455 - INFO - Epoch 6/15 | Train MSE: 0.014021 | Val MSE: 0.012837 | LR: 1.00e-03
# 2026-06-23 11:15:43,468 - INFO - New optimal weights saved. Validation Loss: 0.012837
# 2026-06-23 11:16:46,650 - INFO - Epoch 7/15 | Train MSE: 0.012520 | Val MSE: 0.011994 | LR: 1.00e-03
# 2026-06-23 11:16:46,662 - INFO - New optimal weights saved. Validation Loss: 0.011994
# 2026-06-23 11:17:48,573 - INFO - Epoch 8/15 | Train MSE: 0.011926 | Val MSE: 0.011498 | LR: 1.00e-03
# 2026-06-23 11:17:48,588 - INFO - New optimal weights saved. Validation Loss: 0.011498
# 2026-06-23 11:18:49,884 - INFO - Epoch 9/15 | Train MSE: 0.011659 | Val MSE: 0.011465 | LR: 1.00e-03
# 2026-06-23 11:18:49,896 - INFO - New optimal weights saved. Validation Loss: 0.011465
# 2026-06-23 11:19:52,542 - INFO - Epoch 10/15 | Train MSE: 0.011508 | Val MSE: 0.011455 | LR: 1.00e-03
# 2026-06-23 11:19:52,554 - INFO - New optimal weights saved. Validation Loss: 0.011455
# 2026-06-23 11:20:55,339 - INFO - Epoch 11/15 | Train MSE: 0.011375 | Val MSE: 0.011433 | LR: 1.00e-03
# 2026-06-23 11:20:55,351 - INFO - New optimal weights saved. Validation Loss: 0.011433
# 2026-06-23 11:21:58,162 - INFO - Epoch 12/15 | Train MSE: 0.011281 | Val MSE: 0.011347 | LR: 1.00e-03
# 2026-06-23 11:21:58,175 - INFO - New optimal weights saved. Validation Loss: 0.011347
# 2026-06-23 11:23:01,864 - INFO - Epoch 13/15 | Train MSE: 0.011188 | Val MSE: 0.011010 | LR: 1.00e-03
# 2026-06-23 11:23:01,877 - INFO - New optimal weights saved. Validation Loss: 0.011010
# 2026-06-23 11:24:04,226 - INFO - Epoch 14/15 | Train MSE: 0.011065 | Val MSE: 0.010817 | LR: 1.00e-03
# 2026-06-23 11:24:04,239 - INFO - New optimal weights saved. Validation Loss: 0.010817
# 2026-06-23 11:25:07,853 - INFO - Epoch 15/15 | Train MSE: 0.010979 | Val MSE: 0.011210 | LR: 1.00e-03
# 2026-06-23 11:25:07,853 - INFO - All seed protocols completed successfully.

# %% [markdown]
# ### **Experiment 3: Global All-to-All Entanglement (`strong`)**
# This executes the optimized architecture. It deploys full 3D Euler rotations and global frequency coupling.
#
# This architecture tests the Phase 4 hypothesis: capturing the macroscopic vibration correlations of degrading concrete requires a highly entangled, globally connected quantum topology.

# %%
# !python scripts/run_experiment.py --config configs/ablation_hqae_strong_d3.yaml 2>&1 | tee /content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/strong_d3.log
# Out:
# 2026-06-23 11:25:28,864 - INFO - Compute device allocated: cuda
# 2026-06-23 11:25:28,864 - INFO - Starting Protocol Run | Seed: 42
# 2026-06-23 11:25:28,865 - INFO - System locked to deterministic seed: 42
# 2026-06-23 11:25:28,912 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 11:25:30,274 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 11:26:54,699 - INFO - Epoch 1/15 | Train MSE: 0.040511 | Val MSE: 0.032200 | LR: 1.00e-03
# 2026-06-23 11:26:54,716 - INFO - New optimal weights saved. Validation Loss: 0.032200
# 2026-06-23 11:28:18,818 - INFO - Epoch 2/15 | Train MSE: 0.032009 | Val MSE: 0.032041 | LR: 1.00e-03
# 2026-06-23 11:28:18,834 - INFO - New optimal weights saved. Validation Loss: 0.032041
# 2026-06-23 11:29:41,118 - INFO - Epoch 3/15 | Train MSE: 0.031915 | Val MSE: 0.032086 | LR: 1.00e-03
# 2026-06-23 11:31:05,248 - INFO - Epoch 4/15 | Train MSE: 0.031853 | Val MSE: 0.031923 | LR: 1.00e-03
# 2026-06-23 11:31:05,261 - INFO - New optimal weights saved. Validation Loss: 0.031923
# 2026-06-23 11:32:29,595 - INFO - Epoch 5/15 | Train MSE: 0.031824 | Val MSE: 0.031900 | LR: 1.00e-03
# 2026-06-23 11:32:29,610 - INFO - New optimal weights saved. Validation Loss: 0.031900
# 2026-06-23 11:33:49,854 - INFO - Epoch 6/15 | Train MSE: 0.031779 | Val MSE: 0.031914 | LR: 1.00e-03
# 2026-06-23 11:35:10,531 - INFO - Epoch 7/15 | Train MSE: 0.031739 | Val MSE: 0.031863 | LR: 1.00e-03
# 2026-06-23 11:35:10,544 - INFO - New optimal weights saved. Validation Loss: 0.031863
# 2026-06-23 11:36:30,249 - INFO - Epoch 8/15 | Train MSE: 0.022526 | Val MSE: 0.016095 | LR: 1.00e-03
# 2026-06-23 11:36:30,262 - INFO - New optimal weights saved. Validation Loss: 0.016095
# 2026-06-23 11:37:50,279 - INFO - Epoch 9/15 | Train MSE: 0.014785 | Val MSE: 0.013066 | LR: 1.00e-03
# 2026-06-23 11:37:50,295 - INFO - New optimal weights saved. Validation Loss: 0.013066
# 2026-06-23 11:39:09,088 - INFO - Epoch 10/15 | Train MSE: 0.012301 | Val MSE: 0.011364 | LR: 1.00e-03
# 2026-06-23 11:39:09,100 - INFO - New optimal weights saved. Validation Loss: 0.011364
# 2026-06-23 11:40:28,994 - INFO - Epoch 11/15 | Train MSE: 0.011255 | Val MSE: 0.010744 | LR: 1.00e-03
# 2026-06-23 11:40:29,008 - INFO - New optimal weights saved. Validation Loss: 0.010744
# 2026-06-23 11:41:48,968 - INFO - Epoch 12/15 | Train MSE: 0.010700 | Val MSE: 0.010326 | LR: 1.00e-03
# 2026-06-23 11:41:48,983 - INFO - New optimal weights saved. Validation Loss: 0.010326
# 2026-06-23 11:43:11,635 - INFO - Epoch 13/15 | Train MSE: 0.010422 | Val MSE: 0.010528 | LR: 1.00e-03
# 2026-06-23 11:44:31,259 - INFO - Epoch 14/15 | Train MSE: 0.010328 | Val MSE: 0.010102 | LR: 1.00e-03
# 2026-06-23 11:44:31,273 - INFO - New optimal weights saved. Validation Loss: 0.010102
# 2026-06-23 11:45:51,769 - INFO - Epoch 15/15 | Train MSE: 0.010213 | Val MSE: 0.010078 | LR: 1.00e-03
# 2026-06-23 11:45:51,788 - INFO - New optimal weights saved. Validation Loss: 0.010078
# 2026-06-23 11:45:51,789 - INFO - Starting Protocol Run | Seed: 100
# 2026-06-23 11:45:51,792 - INFO - System locked to deterministic seed: 100
# 2026-06-23 11:45:51,878 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 11:45:51,890 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 11:47:11,941 - INFO - Epoch 1/15 | Train MSE: 0.052679 | Val MSE: 0.032523 | LR: 1.00e-03
# 2026-06-23 11:47:11,961 - INFO - New optimal weights saved. Validation Loss: 0.032523
# 2026-06-23 11:48:31,931 - INFO - Epoch 2/15 | Train MSE: 0.032196 | Val MSE: 0.032352 | LR: 1.00e-03
# 2026-06-23 11:48:31,948 - INFO - New optimal weights saved. Validation Loss: 0.032352
# 2026-06-23 11:49:52,091 - INFO - Epoch 3/15 | Train MSE: 0.032032 | Val MSE: 0.032126 | LR: 1.00e-03
# 2026-06-23 11:49:52,103 - INFO - New optimal weights saved. Validation Loss: 0.032126
# 2026-06-23 11:51:13,547 - INFO - Epoch 4/15 | Train MSE: 0.031953 | Val MSE: 0.032102 | LR: 1.00e-03
# 2026-06-23 11:51:13,559 - INFO - New optimal weights saved. Validation Loss: 0.032102
# 2026-06-23 11:52:33,852 - INFO - Epoch 5/15 | Train MSE: 0.031896 | Val MSE: 0.032077 | LR: 1.00e-03
# 2026-06-23 11:52:33,865 - INFO - New optimal weights saved. Validation Loss: 0.032077
# 2026-06-23 11:53:51,380 - INFO - Epoch 6/15 | Train MSE: 0.031858 | Val MSE: 0.031900 | LR: 1.00e-03
# 2026-06-23 11:53:51,395 - INFO - New optimal weights saved. Validation Loss: 0.031900
# 2026-06-23 11:55:09,331 - INFO - Epoch 7/15 | Train MSE: 0.031858 | Val MSE: 0.031951 | LR: 1.00e-03
# 2026-06-23 11:56:25,601 - INFO - Epoch 8/15 | Train MSE: 0.031831 | Val MSE: 0.031905 | LR: 1.00e-03
# 2026-06-23 11:57:42,978 - INFO - Epoch 9/15 | Train MSE: 0.031819 | Val MSE: 0.031910 | LR: 1.00e-03
# 2026-06-23 11:58:59,140 - INFO - Epoch 10/15 | Train MSE: 0.031782 | Val MSE: 0.031911 | LR: 5.00e-04
# 2026-06-23 12:00:15,896 - INFO - Epoch 11/15 | Train MSE: 0.031738 | Val MSE: 0.031858 | LR: 5.00e-04
# 2026-06-23 12:00:15,909 - INFO - New optimal weights saved. Validation Loss: 0.031858
# 2026-06-23 12:01:34,403 - INFO - Epoch 12/15 | Train MSE: 0.031672 | Val MSE: 0.031310 | LR: 5.00e-04
# 2026-06-23 12:01:34,415 - INFO - New optimal weights saved. Validation Loss: 0.031310
# 2026-06-23 12:02:52,009 - INFO - Epoch 13/15 | Train MSE: 0.030203 | Val MSE: 0.028684 | LR: 5.00e-04
# 2026-06-23 12:02:52,029 - INFO - New optimal weights saved. Validation Loss: 0.028684
# 2026-06-23 12:04:09,899 - INFO - Epoch 14/15 | Train MSE: 0.028171 | Val MSE: 0.026376 | LR: 5.00e-04
# 2026-06-23 12:04:09,913 - INFO - New optimal weights saved. Validation Loss: 0.026376
# 2026-06-23 12:05:28,012 - INFO - Epoch 15/15 | Train MSE: 0.023812 | Val MSE: 0.019299 | LR: 5.00e-04
# 2026-06-23 12:05:28,024 - INFO - New optimal weights saved. Validation Loss: 0.019299
# 2026-06-23 12:05:28,025 - INFO - Starting Protocol Run | Seed: 2026
# 2026-06-23 12:05:28,025 - INFO - System locked to deterministic seed: 2026
# 2026-06-23 12:05:28,066 - INFO - Instantiating Hybrid Quantum Autoencoder (HQAE)...
# 2026-06-23 12:05:28,071 - INFO - Initiating training on cuda for 15 epochs.
# 2026-06-23 12:06:45,358 - INFO - Epoch 1/15 | Train MSE: 0.039797 | Val MSE: 0.032295 | LR: 1.00e-03
# 2026-06-23 12:06:45,373 - INFO - New optimal weights saved. Validation Loss: 0.032295
# 2026-06-23 12:08:05,360 - INFO - Epoch 2/15 | Train MSE: 0.032055 | Val MSE: 0.032070 | LR: 1.00e-03
# 2026-06-23 12:08:05,373 - INFO - New optimal weights saved. Validation Loss: 0.032070
# 2026-06-23 12:09:26,081 - INFO - Epoch 3/15 | Train MSE: 0.031932 | Val MSE: 0.031963 | LR: 1.00e-03
# 2026-06-23 12:09:26,097 - INFO - New optimal weights saved. Validation Loss: 0.031963
# 2026-06-23 12:10:52,303 - INFO - Epoch 4/15 | Train MSE: 0.031855 | Val MSE: 0.031906 | LR: 1.00e-03
# 2026-06-23 12:10:52,317 - INFO - New optimal weights saved. Validation Loss: 0.031906
# 2026-06-23 12:12:18,334 - INFO - Epoch 5/15 | Train MSE: 0.031798 | Val MSE: 0.031907 | LR: 1.00e-03
# 2026-06-23 12:13:41,374 - INFO - Epoch 6/15 | Train MSE: 0.031796 | Val MSE: 0.031880 | LR: 1.00e-03
# 2026-06-23 12:13:41,390 - INFO - New optimal weights saved. Validation Loss: 0.031880
# 2026-06-23 12:15:02,777 - INFO - Epoch 7/15 | Train MSE: 0.031762 | Val MSE: 0.031893 | LR: 1.00e-03
# 2026-06-23 12:16:25,076 - INFO - Epoch 8/15 | Train MSE: 0.031790 | Val MSE: 0.031921 | LR: 1.00e-03
# 2026-06-23 12:17:45,454 - INFO - Epoch 9/15 | Train MSE: 0.021844 | Val MSE: 0.015430 | LR: 1.00e-03
# 2026-06-23 12:17:45,475 - INFO - New optimal weights saved. Validation Loss: 0.015430
# 2026-06-23 12:19:07,224 - INFO - Epoch 10/15 | Train MSE: 0.013938 | Val MSE: 0.012111 | LR: 1.00e-03
# 2026-06-23 12:19:07,240 - INFO - New optimal weights saved. Validation Loss: 0.012111
# 2026-06-23 12:20:28,645 - INFO - Epoch 11/15 | Train MSE: 0.011487 | Val MSE: 0.010882 | LR: 1.00e-03
# 2026-06-23 12:20:28,668 - INFO - New optimal weights saved. Validation Loss: 0.010882
# 2026-06-23 12:21:49,460 - INFO - Epoch 12/15 | Train MSE: 0.010784 | Val MSE: 0.010372 | LR: 1.00e-03
# 2026-06-23 12:21:49,475 - INFO - New optimal weights saved. Validation Loss: 0.010372
# 2026-06-23 12:23:11,283 - INFO - Epoch 13/15 | Train MSE: 0.010375 | Val MSE: 0.010251 | LR: 1.00e-03
# 2026-06-23 12:23:11,297 - INFO - New optimal weights saved. Validation Loss: 0.010251
# 2026-06-23 12:24:33,274 - INFO - Epoch 14/15 | Train MSE: 0.010151 | Val MSE: 0.010219 | LR: 1.00e-03
# 2026-06-23 12:24:33,289 - INFO - New optimal weights saved. Validation Loss: 0.010219
# 2026-06-23 12:25:56,603 - INFO - Epoch 15/15 | Train MSE: 0.009980 | Val MSE: 0.009777 | LR: 1.00e-03
# 2026-06-23 12:25:56,617 - INFO - New optimal weights saved. Validation Loss: 0.009777
# 2026-06-23 12:25:56,617 - INFO - All seed protocols completed successfully.

# %% [markdown]
# ### **Phase 4a: Visualization and Conclusion**
# We parse the generated `.log` file to plot the Train v/s Validation MSE convergence for all 3 experiments

# %%
from src.utils.viz import plot_training_logs, plot_ablation_results

# 1. Visualize Convergence per Topology
plot_training_logs('/content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/none_d3.log', title="Leg-2 Convergence: None Topology (Depth 3)")

plot_training_logs('/content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/basic_d3.log', title="Leg-2 Convergence: Basic Topology (Depth 3)")

plot_training_logs('/content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/strong_d3.log', title="Leg-2 Convergence: Strong Topology (Depth 3)")

# 2. Extract final validation MSEs directly from the logs
def extract_final_mse(log_path):
    final_mses = []
    try:
        with open(log_path, 'r') as f:
            lines = f.readlines()
            for line in lines:
                if "Epoch 15/15" in line:
                    val_mse = float(line.split("Val MSE: ")[1].split(" |")[0])
                    final_mses.append(val_mse)
        # Return average of the 3 seeds
        return sum(final_mses) / len(final_mses) if final_mses else 0
    except FileNotFoundError:
        print(f"Warning: Log file not found at {log_path}")
        return 0

results_4a = {
    'None': extract_final_mse('/content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/none_d3.log'),
    'Basic': extract_final_mse('/content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/basic_d3.log'),
    'Strong': extract_final_mse('/content/drive/MyDrive/spectra-cq-data/logs_phase3_PE11/ablation4a/strong_d3.log')
}

# 3. Plot the Topology Ablation Summary Bar Chart
print("\n")
plot_ablation_results(results_dict=results_4a, title="Phase 4a: Topology Ablation (Final Validation MSE)")
# Out:
# /content/SPECTRA-CQ/src/utils/viz.py:102: UserWarning: AutoMinorLocator does not work on logarithmic scales
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: AutoMinorLocator does not work on logarithmic scales
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### **Ablation 4a: Empirical Observations and Inference**
#
# #### **1. Quantitative Results**
# The HQAE optimization mitigations used:
# * gradient clipping
# * scaling classical latents to $[-\pi, \pi]$
# * topology-specific uniform initialization
#
# Helped the models converge $\leftarrow$ successfully prevented the barren plateaus we observed in Leg 1.
#
# Final Validation MSE (averaged across 3 seeds):
# * **`none`** (Independent $R_x$ rotations): **~0.0087** (Fastest convergence, highly stable)
# * **`basic`** (Ring entanglement): **~0.0119**
# * **`strong`** (All-to-all entanglement): **~0.0131** (High variance; Seed 100 spent 11 epochs trapped on a flat gradient plain before descending).
#
# #### **2. Analysis (Entanglement Penalty)**
# The unentangled `none` architecture significantly outperformed both entangled topologies. The root cause lies in how the classical encoder formats the latent space before it reaches the VQC.
#
# By the time the data hits the 8-qubit bottleneck $\rightarrow$ the classical `Conv2d` layers have already compressed the $64 \times 1000$ CWT spectrogram into 8 highly dense, mathematically distinct macro-features.
#
# When we apply `CNOT` gates to these variables (using `basic` or `strong` topologies) $\implies$ we force these pre-optimized, independent features to mix.
#
# Rather than discovering hidden quantum correlations, this entanglement simply scrambles the classical feature mapping. The classical `ConvTranspose2d` decoder is then forced to expend its parameters trying to untangle this artificial noise to reconstruct the spatial matrix $\leftarrow$ strictly inflates the MSE.
